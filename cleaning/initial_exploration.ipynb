# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = 50
pd.options.display.max_colwidth = 100
pd.options.display.max_rows = 50

# %%
rec1 = pd.read_csv('../data/recipes.csv')

# %%
rec1.rename({'RecipeId': 'id'}, axis=1, inplace=True)

# %%
rec1.head(1)
# Out:
#    id                               Name  AuthorId AuthorName CookTime  \
# 0  38  Low-Fat Berry Blue Frozen Dessert      1533     Dancer    PT24H
#
#   PrepTime TotalTime         DatePublished  \
# 0    PT45M  PT24H45M  1999-08-09T21:46:00Z
#
#                                                                    Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen Dessert recipe from Food.com.
#
#                                                                                                 Images  \
# 0  c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes...
#
#     RecipeCategory  \
# 0  Frozen Desserts
#
#                                                                                               Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol", "Healthy", "Free Of...", "Summer", "Weeknight", "...
#
#   RecipeIngredientQuantities  \
# 0    c("4", "1/4", "1", "1")
#
#                                                    RecipeIngredientParts  \
# 0  c("blueberries", "granulated sugar", "vanilla yogurt", "lemon juice")
#
#    AggregatedRating  ReviewCount  Calories  FatContent  SaturatedFatContent  \
# 0               4.5          4.0     170.9         2.5                  1.3
#
#    CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                 8.0           29.8                 37.1           3.6
#
#    SugarContent  ProteinContent  RecipeServings RecipeYield  \
# 0          30.2             3.2             4.0         NaN
#
#                                                                                     RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stand for 45 minutes, stirring occasionally.", "Transf...

# %%
rec2 = pd.read_csv('../data/recipes_w_search_terms.csv')

# %%
rec2.head(1)
# Out:
#       id                         name  \
# 0  96313  Grilled Garlic Cheese Grits
#
#                                                                                            description  \
# 0  We love grits, this is another good way to serve them. A great alternative to a baked potato whe...
#
#                                                            ingredients  \
# 0  ['water', 'grits', 'salt', 'cheddar cheese', 'garlic', 'olive oil']
#
#                                                                                    ingredients_raw_str  \
# 0  ["4   cups    water","1   cup   uncooked old fashion grits","1   teaspoon    salt","4   ounces  ...
#
#   serving_size  servings  \
# 0    1 (155 g)         8
#
#                                                                                                  steps  \
# 0  ['I a sauce pan, bring water to a boil; slowly add grits and salt, stirring constantly; Reduce h...
#
#                                                                                                   tags  \
# 0  ['time-to-make', 'course', 'main-ingredient', 'preparation', 'occasion', 'side-dishes', 'eggs-da...
#
#                                                     search_terms
# 0  {'diabetic', 'low-calorie', 'vegetarian', 'low-carb', 'side'}

# %%
# rev = pd.read_csv('../data/reviews.csv')

# %%
rec1.shape, rec2.shape
# Out:
# ((522517, 28), (494963, 10))

# %%
rec = pd.merge(rec1, rec2, on='id')

# %%
rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 494949 entries, 0 to 494948
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          494949 non-null  int64
#  1   Name                        494949 non-null  object
#  2   AuthorId                    494949 non-null  int64
#  3   AuthorName                  494949 non-null  object
#  4   CookTime                    422827 non-null  object
#  5   PrepTime                    494949 non-null  object
#  6   TotalTime                   494949 non-null  object
#  7   DatePublished               494949 non-null  object
#  8   Description                 494946 non-null  object
#  9   Images                      494949 non-null  object
#  10  RecipeCategory              494294 non-null  object
#  11  Keywords                    480168 non-null  object
#  12  RecipeIngredientQuantities  494946 non-null  object
#  13  RecipeIngredientParts       494949 non-null  object
#  14  AggregatedRating            258307 non-null  float64
#  15  ReviewCount                 263768 non-null  float64
#  16  Calories                    494949 non-null  float64
#  17  FatContent                  494949 non-null  float64
#  18  SaturatedFatContent         494949 non-null  float64
#  19  CholesterolContent          494949 non-null  float64
#  20  SodiumContent               494949 non-null  float64
#  21  CarbohydrateContent         494949 non-null  float64
#  22  FiberContent                494949 non-null  float64
#  23  SugarContent                494949 non-null  float64
#  24  ProteinContent              494949 non-null  float64
#  25  RecipeServings              322298 non-null  float64
#  26  RecipeYield                 162243 non-null  object
#  27  RecipeInstructions          494949 non-null  object
#  28  name                        494949 non-null  object
#  29  description                 485351 non-null  object
#  30  ingredients                 494949 non-null  object
#  31  ingredients_raw_str         494949 non-null  object
#  32  serving_size                494949 non-null  object
#  33  servings                    494949 non-null  int64
#  34  steps                       494949 non-null  object
#  35  tags                        494949 non-null  object
#  36  search_terms                494949 non-null  object
# dtypes: float64(12), int64(3), object(22)
# memory usage: 143.5+ MB

# %%
rec[['Keywords','RecipeCategory', 'tags', 'search_terms']]
# Out:
#                                                                                                    Keywords  \
# 0       c("Dessert", "Low Protein", "Low Cholesterol", "Healthy", "Free Of...", "Summer", "Weeknight", "...
# 1       c("Chicken Thigh & Leg", "Chicken", "Poultry", "Meat", "Asian", "Indian", "Weeknight", "Stove Top")
# 2                                     c("Low Protein", "Low Cholesterol", "Healthy", "Summer", "< 60 Mins")
# 3                            c("Beans", "Vegetable", "Low Cholesterol", "Weeknight", "Broil/Grill", "Oven")
# 4                    c("Low Protein", "Vegan", "Low Cholesterol", "Healthy", "Winter", "< 60 Mins", "Easy")
# ...                                                                                                     ...
# 494944                                          c("Poultry", "Meat", "Egg Free", "Free Of...", "< 30 Mins")
# 494945  c("Cheese", "Meat", "Very Low Carbs", "High Protein", "Egg Free", "Free Of...", "High In...", "B...
# 494946                                                             c("Egg Free", "Free Of...", "< 30 Mins")
# 494947                                                                         c("Free Of...", "< 15 Mins")
# 494948                                                 c("Pork", "Meat", "High In...", "< 4 Hours", "Easy")
#
#          RecipeCategory  \
# 0       Frozen Desserts
# 1        Chicken Breast
# 2             Beverages
# 3              Soy/Tofu
# 4             Vegetable
# ...                 ...
# 494944          Chicken
# 494945             Pork
# 494946   Very Low Carbs
# 494947          Mexican
# 494948        Spaghetti
#
#                                                                                                        tags  \
# 0       ['weeknight', 'time-to-make', 'course', 'preparation', 'occasion', 'low-protein', 'healthy', '5-...
# 1       ['weeknight', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'main-dish'...
# 2       ['60-minutes-or-less', 'time-to-make', 'course', 'preparation', 'occasion', 'low-protein', 'heal...
# 3       ['weeknight', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion',...
# 4       ['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'o...
# ...                                                                                                     ...
# 494944  ['30-minutes-or-less', 'time-to-make', 'main-ingredient', 'preparation', 'for-1-or-2', 'poultry'...
# 494945  ['bacon', '30-minutes-or-less', 'time-to-make', 'main-ingredient', 'preparation', 'very-low-carb...
# 494946  ['30-minutes-or-less', 'time-to-make', 'main-ingredient', 'preparation', 'very-low-carbs', 'seaf...
# 494947  ['15-minutes-or-less', 'time-to-make', 'course', 'cuisine', 'preparation', 'casseroles', 'main-d...
# 494948  ['time-to-make', 'course', 'main-ingredient', 'preparation', 'casseroles', 'main-dish', 'pasta',...
#
#                                                                             search_terms
# 0          {'low-calorie', 'low-sodium', 'dessert', 'healthy', 'gluten-free', 'low-fat'}
# 1                                                     {'indian', 'dinner', 'low-sodium'}
# 2                                                   {'healthy', 'low-fat', 'low-sodium'}
# 3                                      {'side', 'low-calorie', 'vegetarian', 'low-carb'}
# 4       {'low-calorie', 'vegetarian', 'healthy', 'low-carb', 'low-fat', 'soup', 'vegan'}
# ...                                                                                  ...
# 494944                                                  {'bread', 'barbecue', 'chicken'}
# 494945                                                       {'gluten-free', 'low-carb'}
# 494946                                             {'gluten-free', 'low-carb', 'shrimp'}
# 494947                                    {'mexican', 'casserole', 'dinner', 'low-carb'}
# 494948                                           {'dinner', 'italian', 'pasta', 'baked'}
#
# [494949 rows x 4 columns]

# %%
rec.head(5)
# Out:
#    id                               Name  AuthorId      AuthorName CookTime  \
# 0  38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer    PT24H
# 1  39                            Biryani      1567        elly9812    PT25M
# 2  40                      Best Lemonade      1566  Stephen Little     PT5M
# 3  41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz    PT20M
# 4  42                       Cabbage Soup      1538       Duckie067    PT30M
#
#   PrepTime TotalTime         DatePublished  \
# 0    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                                                                            Description  \
# 0                          Make and share this Low-Fat Berry Blue Frozen Dessert recipe from Food.com.
# 1                                                    Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keeping cookbooks.  You must use a *zester* in order to...
# 3  This dish is best prepared a day in advance to allow the ingredients to soak in  the marinade ov...
# 4                                               Make and share this Cabbage Soup recipe from Food.com.
#
#                                                                                                 Images  \
# 0  c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes...
# 1  c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes...
# 2  c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes...
# 3  c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes...
# 4  "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/4...
#
#     RecipeCategory  \
# 0  Frozen Desserts
# 1   Chicken Breast
# 2        Beverages
# 3         Soy/Tofu
# 4        Vegetable
#
#                                                                                               Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol", "Healthy", "Free Of...", "Summer", "Weeknight", "...
# 1  c("Chicken Thigh & Leg", "Chicken", "Poultry", "Meat", "Asian", "Indian", "Weeknight", "Stove Top")
# 2                                c("Low Protein", "Low Cholesterol", "Healthy", "Summer", "< 60 Mins")
# 3                       c("Beans", "Vegetable", "Low Cholesterol", "Weeknight", "Broil/Grill", "Oven")
# 4               c("Low Protein", "Vegan", "Low Cholesterol", "Healthy", "Winter", "< 60 Mins", "Easy")
#
#                                                                             RecipeIngredientQuantities  \
# 0                                                                              c("4", "1/4", "1", "1")
# 1  c("1", "4", "2", "2", "8", "1/4", "8", "1/2", "1", "1", "1/4", "1/4", "1/2", "1/4", "2", "3", NA...
# 2                                                              c("1 1/2", "1", NA, "1 1/2", NA, "3/4")
# 3                   c("12", "1", "2", "1", "10", "1", "3", "2", "2", "2", "1", "2", "1/2", "1/4", "4")
# 4                                                                          c("46", "4", "1", "2", "1")
#
#                                                                                  RecipeIngredientParts  \
# 0                                c("blueberries", "granulated sugar", "vanilla yogurt", "lemon juice")
# 1  c("saffron", "milk", "hot green chili peppers", "onions", "garlic", "clove", "peppercorns", "car...
# 2                  c("sugar", "lemons, rind of", "lemon, zest of", "fresh water", "fresh lemon juice")
# 3  c("extra firm tofu", "eggplant", "zucchini", "mushrooms", "soy sauce", "low sodium soy sauce", "...
# 4                                     c("plain tomato juice", "cabbage", "onion", "carrots", "celery")
#
#    AggregatedRating  ReviewCount  Calories  FatContent  SaturatedFatContent  \
# 0               4.5          4.0     170.9         2.5                  1.3
# 1               3.0          1.0    1110.7        58.8                 16.6
# 2               4.5         10.0     311.1         0.2                  0.0
# 3               4.5          2.0     536.1        24.0                  3.8
# 4               4.5         11.0     103.6         0.4                  0.1
#
#    CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                 8.0           29.8                 37.1           3.6
# 1               372.8          368.4                 84.4           9.0
# 2                 0.0            1.8                 81.5           0.4
# 3                 0.0         1558.6                 64.2          17.3
# 4                 0.0          959.3                 25.1           4.8
#
#    SugarContent  ProteinContent  RecipeServings RecipeYield  \
# 0          30.2             3.2             4.0         NaN
# 1          20.4            63.4             6.0         NaN
# 2          77.2             0.3             4.0         NaN
# 3          32.1            29.3             2.0    4 kebabs
# 4          17.7             4.3             4.0         NaN
#
#                                                                                     RecipeInstructions  \
# 0  c("Toss 2 cups berries with sugar.", "Let stand for 45 minutes, stirring occasionally.", "Transf...
# 1  c("Soak saffron in warm milk for 5 minutes and puree in blender.", "Add chiles, onions, ginger, ...
# 2  c("Into a 1 quart Jar with tight fitting lid, put sugar and lemon peel, or zest;  add 1 1/2 cups...
# 3  c("Drain the tofu, carefully squeezing out excess water,  and pat dry with paper towels.", "Cut ...
# 4  c("Mix everything together and bring to a boil.", "Reduce heat and simmer for 30 minutes (longer...
#
#                                 name  \
# 0  Low-Fat Berry Blue Frozen Dessert
# 1                            Biryani
# 2                      Best Lemonade
# 3     Carina's Tofu-Vegetable Kebabs
# 4                       Cabbage Soup
#
#                                                                                            description  \
# 0                                              This is yummy and low-fat, it always turns out perfect.
# 1                                                                                         Delhi, India
# 2  This is from one of my  first Good House Keeping cookbooks.  You must use a *zester* in order to...
# 3  This dish is best prepared a day in advance to allow the ingredients to soak in  the marinade ov...
# 4                                                                                                  NaN
#
#                                                                                            ingredients  \
# 0                                 ['blueberries', 'granulated sugar', 'vanilla yogurt', 'lemon juice']
# 1  ['saffron', 'milk', 'hot green chili peppers', 'onions', 'garlic', 'clove', 'peppercorns', 'card...
# 2          ['sugar', 'lemons%2c rind of', 'fresh water', 'fresh lemon juice', 'ice cube', 'club soda']
# 3  ['extra firm tofu', 'eggplant', 'zucchini', 'red pepper', 'mushrooms', 'baby corn', 'soy sauce',...
# 4                                      ['plain tomato juice', 'cabbage', 'onion', 'carrots', 'celery']
#
#                                                                                    ingredients_raw_str  \
# 0  ["4   cups    blueberries, fresh or frozen ","1/4  cup    granulated sugar","1   cup    vanilla ...
# 1  ["1   tablespoon    saffron","4   teaspoons    milk, warm ","2       hot green chili peppers, as...
# 2  ["1 1/2  cups    sugar","1   tablespoon    lemons, rind of or 1   tablespoon    lemon, zest of, ...
# 3  ["12   ounces    extra firm tofu, water-packed ","1   medium    eggplant","2   small    zucchini...
# 4  ["46   ounces    plain tomato juice","4   cups    cabbage, shredded ","1   medium    onion, chop...
#
#   serving_size  servings  \
# 0    1 (225 g)         4
# 1    1 (799 g)         6
# 2    1 (212 g)         4
# 3    1 (932 g)         2
# 4    1 (493 g)         4
#
#                                                                                                  steps  \
# 0  ['Toss 2 cups berries with sugar.', 'Let stand for 45 minutes, stirring occasionally.', 'Transfe...
# 1  ['Soak saffron in warm milk for 5 minutes and puree in blender.', 'Add chiles, onions, ginger, g...
# 2  ['Into a 1 quart Jar with tight fitting lid, put sugar and lemon peel, or zest;  add 1 1/2 cups ...
# 3  ['Drain the tofu, carefully squeezing out excess water,  and pat dry with paper towels.', 'Cut t...
# 4  ['Mix everything together and bring to a boil.', 'Reduce heat and simmer for 30 minutes (longer ...
#
#                                                                                                   tags  \
# 0  ['weeknight', 'time-to-make', 'course', 'preparation', 'occasion', 'low-protein', 'healthy', '5-...
# 1  ['weeknight', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'main-dish'...
# 2  ['60-minutes-or-less', 'time-to-make', 'course', 'preparation', 'occasion', 'low-protein', 'heal...
# 3  ['weeknight', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion',...
# 4  ['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'o...
#
#                                                                        search_terms
# 0     {'low-calorie', 'low-sodium', 'dessert', 'healthy', 'gluten-free', 'low-fat'}
# 1                                                {'indian', 'dinner', 'low-sodium'}
# 2                                              {'healthy', 'low-fat', 'low-sodium'}
# 3                                 {'side', 'low-calorie', 'vegetarian', 'low-carb'}
# 4  {'low-calorie', 'vegetarian', 'healthy', 'low-carb', 'low-fat', 'soup', 'vegan'}

# %%
# https://data.world/alexandra/generic-food-database/workspace/file?filename=generic-food.csv
foods = pd.read_csv('../data/generic-food.csv')

# %%
foods.GROUP.value_counts()
# Out:
# Aquatic foods                  166
# Vegetables                     130
# Fruits                         130
# Herbs and Spices               108
# Dishes                          51
# Cereals and cereal products     48
# Animal foods                    44
# Baking goods                    33
# Beverages                       30
# Confectioneries                 29
# Nuts                            27
# Pulses                          26
# Milk and milk products          23
# Gourds                          17
# Soy                              9
# Cocoa and cocoa products         8
# Snack foods                      8
# Fats and oils                    8
# Coffee and coffee products       5
# Teas                             3
# Eggs                             1
# Baby foods                       1
# Unclassified                     1
# Herbs and spices                 1
# Name: GROUP, dtype: int64

# %%
foods.loc[foods.GROUP=='Animal foods', :]
# Out:
#                         FOOD NAME           SCIENTIFIC NAME         GROUP  \
# 298                        Beaver         Castor canadensis  Animal foods
# 301                         Bison               Bison bison  Animal foods
# 302                    Black bear          Ursus americanus  Animal foods
# 308                     Wild boar                Sus scrofa  Animal foods
# 313                    Brown bear              Ursus arctos  Animal foods
# 314                       Buffalo           Bubalus bubalis  Animal foods
# 322                       Caribou         Rangifer tarandus  Animal foods
# 332  Chicken (Cock, Hen, Rooster)             Gallus gallus  Animal foods
# 351                     Mule deer                Odocoileus  Animal foods
# 356                  Mallard duck        Anas platyrhynchos  Animal foods
# 362                           Elk         Cervus canadensis  Animal foods
# 363                           Emu  Dromaius novaehollandiae  Animal foods
# 371                 Greylag goose               Anser anser  Animal foods
# 376                    Guinea hen          Numida meleagris  Animal foods
# 381                         Horse            Equus caballus  Animal foods
# 413                         Moose               Alces alces  Animal foods
# 417                       Muskrat        Ondatra zibethicus  Animal foods
# 427                       Opossum      Didelphis virginiana  Animal foods
# 428                       Ostrich          Struthio camelus  Animal foods
# 433                   Velvet duck           Melanitta fusca  Animal foods
# 436                      Pheasant       Phasianus colchicus  Animal foods
# 444                    Polar bear           Ursus maritimus  Animal foods
# 449               European rabbit               Oryctolagus  Animal foods
# 450                       Raccoon             Procyon lotor  Animal foods
# 481          Sheep (Mutton, Lamb)                Ovis aries  Animal foods
# 489                         Squab                   Columba  Animal foods
# 490                      Squirrel                 Sciuridae  Animal foods
# 503                        Turkey       Meleagris gallopavo  Animal foods
# 504           Cattle (Beef, Veal)                Bos taurus  Animal foods
# 533                          Deer                  Cervidae  Animal foods
# 537        Arctic ground squirrel       Urocitellus parryii  Animal foods
# 538                        Rabbit                 Leporidae  Animal foods
# 539                 Domestic goat     Capra aegagrus hircus  Animal foods
# 540                       Beefalo  Bos taurus X Bison bison  Animal foods
# 541                      Antelope              Artiodactyla  Animal foods
# 547   Domestic pig (Piglet, Pork)      Sus scrofa domestica  Animal foods
# 552              Great horned owl          Bubo virginianus  Animal foods
# 553                         Quail               Phasianidae  Animal foods
# 588  Anatidae (Duck, Goose, Swan)                  Anatidae  Animal foods
# 593                 Mountain hare             Lepus timidus  Animal foods
# 609                Rock ptarmigan              Lagopus muta  Animal foods
# 622     Columbidae (Dove, Pigeon)                Columbidae  Animal foods
# 670            Other meat product                       NaN  Animal foods
# 881                  Animal foods                       NaN  Animal foods
#
#          SUB GROUP
# 298        Rodents
# 301        Bovines
# 302  Other mammals
# 308          Swine
# 313  Other mammals
# 314        Bovines
# 322        Venison
# 332        Poultry
# 351        Venison
# 356        Poultry
# 362        Venison
# 363        Poultry
# 371        Poultry
# 376        Poultry
# 381        Equines
# 413        Venison
# 417        Rodents
# 427     Marsupials
# 428        Poultry
# 433        Poultry
# 436        Poultry
# 444  Other mammals
# 449     Lagomorphs
# 450  Other mammals
# 481           Ovis
# 489        Poultry
# 490        Rodents
# 503        Poultry
# 504        Bovines
# 533        Venison
# 537        Rodents
# 538     Lagomorphs
# 539         Caprae
# 540        Bovines
# 541        Venison
# 547          Swine
# 552        Poultry
# 553        Poultry
# 588        Poultry
# 593     Lagomorphs
# 609        Poultry
# 622        Poultry
# 670  Meat products
# 881   Animal foods
